# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# <ol>
#     <li>Python</li>
#     <li>R</li>
#     <li>Javascript</li>
#
# </ol>

# %% [markdown]
# Some of the commonly libraries used by Data Scientists include:
# <ol>
#     <li>NumPy</li>
#     <li>SciPy</li>
#     <li>Matplotlib</li>
#
# </ol>

# %% [markdown]
# <table>
#     <tr>
#         <th>Data Science Tools</th>
#     </tr>
#      <tr>
#         <td>RStudio</td>
#     </tr>
#      <tr>
#         <td>VS Code</td>
#     </tr>
#      <tr>
#         <td>Jupyter</td>
#     </tr>
# </table>

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
#  This will convert 200 minutes to hours by diving by 60

minutes = 200
hours = minutes // 60
remaining_minutes = minutes % 60
print(f"{hours} hours and {remaining_minutes} minutes")
# Out:
# 3 hours and 20 minutes

# %% [markdown]
# <b>Objectives:</b>
# <ul>
#     In this notebook we covered the following:
#     <li>Open and write n a new notebook (code or markdown)</li>
#     <li>Text Formating in Jupyter Notebook </li>
#     <li>Basics of Python programming language</li>
#
# </ul>

# %% [markdown]
# ## Author :
#
# IRINIMBABAZI Jean Marie Vianney
